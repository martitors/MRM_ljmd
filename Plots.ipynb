# %%
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler

from matplotlib.ticker import ScalarFormatter

# %%
############################## SERIAL PLOT ##################################

n_opts = [1,2,4,8,16]
names = ['Baseline','\n-O3','More Optimization Flag','\nNewtons 3rd law','No expensive math']
#fake times, you need to replace this with values
times_108 = [16.303,12.587,2.958,1.29,1.46] 
times_2916 = [300.307,169.68,100.272,48.614,46.378]
times_78732 = [2223.907,766.217,743.296,389.974,370.301]

bar_width = 0.2
bar_positions1 = np.arange(len(n_opts))
bar_positions2 = bar_positions1 + bar_width
bar_positions3 = bar_positions2 + bar_width

plt.rcParams['axes.prop_cycle'] = cycler('color', plt.get_cmap('Paired').colors[::2])

plt.figure(figsize=(10,5))
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.bar(bar_positions1,[times_108[0]/t for t in times_108],label = "108 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions2,[times_2916[0]/t for t in times_2916],label = "2916 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions3,[times_78732[0]/t for t in times_78732],label = "78732 atoms", width=bar_width,edgecolor = "black")
plt.xticks(bar_positions2,names)
plt.title('SERIAL Benchmark',fontsize = 12)
plt.ylabel("Speedup")
plt.yscale('log')
plt.legend()
plt.savefig('plots/Serial_bm_1.pdf',format='pdf')


plt.figure(figsize=(10,5))
plt.plot(bar_positions1,times_108,'o-',label = "108 atoms",linewidth=2.5)
plt.plot(bar_positions1,times_2916,'o-',label = "2916 atoms",linewidth=2.5)
plt.plot(bar_positions1,times_78732,'o-',label = "78732 atoms",linewidth=2.5)
plt.xticks(bar_positions1,names)
plt.title('SERIAL Benchmark',fontsize = 12)
plt.ylabel("Time (s)")
plt.yscale('log')
plt.legend()
plt.savefig('plots/Serial_bm_2.pdf',format='pdf')


plt.show()

# %%
############################## OMP PLOT ##################################

n_threads = [1,2,4,8,16,32]
#fake times, you need to replace this with values
times_108 = [1.093,0.352,0.190,0.171,0.255,0.517]
times_2916 = [47.483,24.171,12.474,6.566,3.622,2.098]
times_78732 = [394.006,212.447,109.337,52.601,27.900,15.105]

bar_width = 0.2
bar_positions1 = np.arange(len(n_threads))
#O_n=np.array([1./(bar_positions1[i]+1) for i in range (len(bar_positions1))])
bar_positions2 = bar_positions1 + bar_width
bar_positions3 = bar_positions2 + bar_width

plt.rcParams['axes.prop_cycle'] = cycler('color', plt.get_cmap('Paired').colors[::2])

plt.figure(figsize=(10,5))
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.bar(bar_positions1,[times_108[0]/t for t in times_108],label = "108 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions2,[times_2916[0]/t for t in times_2916],label = "2916 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions3,[times_78732[0]/t for t in times_78732],label = "78732 atoms", width=bar_width,edgecolor = "black")
plt.xticks(bar_positions2,n_threads)
plt.title('OpenMP Benchmark',fontsize = 12)
plt.xlabel("N Threads")
plt.ylabel("Speedup")
plt.yscale('log')
plt.legend()
plt.savefig("OpenMP_bm_1.pdf",format='pdf')

plt.figure(figsize=(10,5))
plt.plot(bar_positions1,times_108,'o-',label = "108 atoms",linewidth=2.5)
plt.plot(bar_positions1,times_2916,'o-',label = "2916 atoms",linewidth=2.5)
plt.plot(bar_positions1,times_78732,'o-',label = "78732 atoms",linewidth=2.5)
#plt.plot(bar_positions1,O_n,'o--',label = "O(N)",linewidth=1.5,color='grey')
plt.xticks(bar_positions1,n_threads)
plt.title('OpenMP Benchmark',fontsize = 12)
plt.xlabel("N Threads")
plt.ylabel("Time (s)")
plt.yscale('log')
plt.legend()
plt.savefig("OpenMP_bm_2.pdf",format='pdf')

plt.show()

# %%
############################## MPI PLOT ##################################

n_procs = [1,2,4,8,16,32,64,128,256]
#fake times, you need to replace this with values
times_108 = [1.109,0.368,0.186,0.151,0.150,0.183,0.283,0.492,0.529]
times_2916 = [47.323,24.444,12.487,6.563,3.613,2.257,1.380,1.425,1.111]
times_78732 = [388.696,193.870,96.990,48.907,25.352,15.113,7.849,4.418,2.473]

bar_width = 0.2
bar_positions1 = np.arange(len(n_procs))
bar_positions2 = bar_positions1 + bar_width
bar_positions3 = bar_positions2 + bar_width

plt.rcParams['axes.prop_cycle'] = cycler('color', plt.get_cmap('Paired').colors[::2])

plt.figure(figsize=(10,5))
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.bar(bar_positions1,[times_108[0]/t for t in times_108],label = "108 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions2,[times_2916[0]/t for t in times_2916],label = "2916 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions3,[times_78732[0]/t for t in times_78732],label = "78732 atoms", width=bar_width,edgecolor = "black")
plt.xticks(bar_positions2,n_procs)
plt.title('MPI Benchmark',fontsize = 12)
plt.ylabel("Speedup")
plt.xlabel("N Procs")
plt.yscale('log')
plt.legend()
plt.savefig("MPI_bm_1.pdf",format='pdf')

plt.figure(figsize=(10,5))
plt.plot(bar_positions1,times_108,'o-',label = "108 atoms",linewidth=2.5)
plt.plot(bar_positions1,times_2916,'o-',label = "2916 atoms",linewidth=2.5)
plt.plot(bar_positions1,times_78732,'o-',label = "78732 atoms",linewidth=2.5)
plt.xticks(bar_positions1,n_procs)
plt.title('MPI Benchmark',fontsize = 12)
plt.xlabel("N Procs")
plt.ylabel("Time (s)")
plt.yscale('log')
plt.legend()
plt.savefig("MPI_bm_2.pdf",format='pdf')

plt.show()

# %%
############################## HYBRID PLOT ##################################

n_procs = [1,2,4,8,16,32,64,128,256]
#fake times, you need to replace this with values
times_108 = [1.e+4/procs for procs in n_procs]
times_2916 = [1.e+5/(procs**2) for procs in n_procs]
times_78732 = [1.e+6/(procs**3) for procs in n_procs]

bar_width = 0.2
bar_positions1 = np.arange(len(n_procs))
bar_positions2 = bar_positions1 + bar_width
bar_positions3 = bar_positions2 + bar_width

plt.rcParams['axes.prop_cycle'] = cycler('color', plt.get_cmap('Paired').colors[::2])

plt.figure(figsize=(7,5))
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.bar(bar_positions1,[times_108[0]/t for t in times_108],label = "108 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions2,[times_2916[0]/t for t in times_2916],label = "2916 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions3,[times_78732[0]/t for t in times_78732],label = "78732 atoms", width=bar_width,edgecolor = "black")
plt.xticks(bar_positions2,n_procs)
plt.title('Hybrid MPI + OpenMP Benchmark',fontsize = 12)
plt.xlabel("N Procs * N Threads")
plt.ylabel("Total Speedup")
plt.yscale('log')
plt.legend()

plt.figure(figsize=(7,5))
plt.plot(bar_positions1,times_108,'o-',label = "108 atoms",linewidth=2.5)
plt.plot(bar_positions1,times_2916,'o-',label = "2916 atoms",linewidth=2.5)
plt.plot(bar_positions1,times_78732,'o-',label = "78732 atoms",linewidth=2.5)
plt.xticks(bar_positions1,n_procs)
plt.title('Hybrid MPI + OpenMP Benchmark',fontsize = 12)
plt.xlabel("N Procs * N Threads")
plt.ylabel("Time (s)")
plt.yscale('log')
plt.legend()

plt.show()

# %%
n_opts = [1,2,4,8,16,32,64]
names = ['Baseline','Compiler Opt','Optimal (N^2)','Cell List','MPI','OpenMP','Hybrid']
#fake times, you need to replace this with values
times_108 = [1.e+4/opts for opts in n_opts]
times_2916 = [1.e+5/(opts**2) for opts in n_opts]
times_78732 = [1.e+6/(opts**3) for opts in n_opts]

bar_width = 0.2
bar_positions1 = np.arange(len(n_opts))
bar_positions2 = bar_positions1 + bar_width
bar_positions3 = bar_positions2 + bar_width

plt.rcParams['axes.prop_cycle'] = cycler('color', plt.get_cmap('Paired').colors[::2])

plt.figure(figsize=(10,5))
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.bar(bar_positions1,[times_108[0]/t for t in times_108],label = "108 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions2,[times_2916[0]/t for t in times_2916],label = "2916 atoms", width=bar_width,edgecolor = "black")
plt.bar(bar_positions3,[times_78732[0]/t for t in times_78732],label = "78732 atoms", width=bar_width,edgecolor = "black")
plt.xticks(bar_positions2,names)
plt.title('Total Speedup Comparison',fontsize = 12)
plt.ylabel("Total Speedup")
plt.yscale('log')
plt.legend()

plt.show()
